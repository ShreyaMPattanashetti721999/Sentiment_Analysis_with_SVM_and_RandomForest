# %% [markdown]
# # NLP Assignment 1 (40% of grade): Sentiment Analysis from Tweets
#
# This coursework will involve you implementing functions for a text classifier, which you will train to identify the **sentiment expressed in a text** in a dataset of approx. 27,000 entries, which will be split into a 80%/20% training/test split.
#
# In this template you are given the basis for that implementation, though some of the functions are missing, which you have to fill in.
#
# Follow the instructions file **NLP_Assignment_1_Instructions.pdf** for details of each question - the outline of what needs to be achieved for each question is as below.
#
# You must submit all **ipython notebooks and extra resources you need to run the code if you've added them** in the code submission, and a **2 page report (pdf)** in the report submission on QMPlus where you report your methods and findings according to the instructions file for each question.

# %%
import csv                               # csv reader
from sklearn.svm import LinearSVC
from nltk.classify import SklearnClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import precision_recall_fscore_support # to report on precision and recall
import numpy as np
import re

# %%
def load_data(path):
    """Load data from a tab-separated file and append it to raw_data."""
    with open(path) as f:
        reader = csv.reader(f, delimiter='\t')
        for line in reader:
            if line[0] == "Id":  # skip header
                continue
            (label, text) = parse_data_line(line)
            raw_data.append((text, label))

def split_and_preprocess_data(percentage):
    """Split the data between train_data and test_data according to the percentage
    and performs the preprocessing."""
    num_samples = len(raw_data)
    num_training_samples = int((percentage * num_samples))
    for (text, label) in raw_data[:num_training_samples]:
        train_data.append((to_feature_vector(pre_process(text)),label))
    for (text, label) in raw_data[num_training_samples:]:
        test_data.append((to_feature_vector(pre_process(text)),label))

# %% [markdown]
# # Question 1: Input and Basic preprocessing (10 marks)

# %%
def parse_data_line(data_line):
    # Should return a tuple of the label as just positive or negative and the statement
    # e.g. (label, statement)
    label, text = data_line[1], data_line[2]
    return (label, text)
    #return (None, None)

# %%
# Input: a string of one statement
def pre_process(text):
    # Should return a list of tokens
    # DESCRIBE YOUR METHOD IN WORDS
    #print("original:", text)
    # sentence segmentation - assume already done
    # word tokenisation
    text = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1 \2", text) # separates punctuation at ends of strings
    text = re.sub(r"([.,;:!?'\"“\(\)])(\w)", r"\1 \2", text) # separates punctuation at beginning of strings
    print("tokenising:", text)
    tokens = re.split(r"\s+",text)
    # normalisation - only by lower casing for now
    tokens = [t.lower() for t in tokens]
    return tokens

# %% [markdown]
# # Question 2: Basic Feature Extraction (20 marks)

# %%
global_feature_dict = {} # A global dictionary of features

def to_feature_vector(tokens):
    # Should return a dictionary containing features as keys, and weights as values
    # DESCRIBE YOUR METHOD IN WORDS
    feature_vector = {}
    for token in tokens:
        feature_vector[token] = 1  # Binary feature, 1 if the feature is present, 0 if it's not
        global_feature_dict[token] = global_feature_dict.get(token, 0) + 1  # Increment count in the global feature dictionary
    return feature_vector

# %%
# TRAINING AND VALIDATING OUR CLASSIFIER

def train_classifier(data):
    print("Training Classifier...")
    pipeline =  Pipeline([('svc', LinearSVC())])
    return SklearnClassifier(pipeline).train(data)

# %% [markdown]
# # Question 3: Cross-validation (20 marks)

# %%
#solution
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
from sklearn.model_selection import KFold
import numpy as np

def cross_validate(dataset, folds):
    results = []
    kf = KFold(n_splits=folds, shuffle=True, random_state=42)

    for train_index, test_index in kf.split(dataset):
        train_data = [dataset[i] for i in train_index]
        test_data = [dataset[i] for i in test_index]

        classifier = train_classifier(train_data)
        predicted_labels = predict_labels([data[0] for data in test_data], classifier)
        true_labels = [data[1] for data in test_data]

        report = classification_report(true_labels, predicted_labels, output_dict=True)
        results.append(report)

    # Calculate average scores over all folds
    avg_results = {
        'precision': np.mean([result['macro avg']['precision'] for result in results]),
        'recall': np.mean([result['macro avg']['recall'] for result in results]),
        'f1-score': np.mean([result['macro avg']['f1-score'] for result in results]),
        'accuracy': np.mean([result['accuracy'] for result in results])
    }

    return avg_results

# %%
# PREDICTING LABELS GIVEN A CLASSIFIER

def predict_labels(samples, classifier):
    """Assuming preprocessed samples, return their predicted labels from the classifier model."""
    return classifier.classify_many(samples)

def predict_label_from_raw(sample, classifier):
    """Assuming raw text, return its predicted label from the classifier model."""

    return classifier.classify(to_feature_vector(pre_process(sample)))

# %%
# MAIN

# loading reviews
# initialize global lists that will be appended to by the methods below
raw_data = []          # the filtered data from the dataset file
train_data = []        # the pre-processed training data as a percentage of the total dataset
test_data = []         # the pre-processed test data as a percentage of the total dataset


# references to the data files
data_file_path = 'sentiment-dataset.tsv'

# Do the actual stuff (i.e. call the functions we've made)
# We parse the dataset and put it in a raw data list
print("Now %d rawData, %d trainData, %d testData" % (len(raw_data), len(train_data), len(test_data)),
      "Preparing the dataset...",sep='\n')

load_data(data_file_path)

# We split the raw dataset into a set of training data and a set of test data (80/20)
# You do the cross validation on the 80% (training data)
# We print the number of training samples and the number of features before the split
print("Now %d rawData, %d trainData, %d testData" % (len(raw_data), len(train_data), len(test_data)),
      "Preparing training and test data...",sep='\n')

split_and_preprocess_data(0.8)

# We print the number of training samples and the number of features after the split
print("After split, %d rawData, %d trainData, %d testData" % (len(raw_data), len(train_data), len(test_data)),
      "Training Samples: ", len(train_data), "Features: ", len(global_feature_dict), sep='\n')
# Out:
# Now 0 rawData, 0 trainData, 0 testData
# Preparing the dataset...
# Now 33540 rawData, 0 trainData, 0 testData
# Preparing training and test data...
# tokenising: Literally so excited I ' m going to a Sam Smith concert in October
# tokenising: @AngryRaiderFan I know . This , TPP , expanded wars and drone strikes , mass surveillance , on and on ...
# tokenising: @rinashah I have been using Moto G 2nd Gen for over a month now and it ' s an absolute delight . Stock Android . Good design . Best .
# tokenising: Juan  Just heard Green Day ' s ' Time of our life ' for the 1st time since leaving florida and i burst into tears . I miss everyone ...  Kellogg
# tokenising: So Fidel Castro has died .  Don ' t worry , George Soros is willing to fill his shoes as Most Wicked Man In The World #wicked #publicenemy1
# tokenising: cried for every episode of Dream High 2 starting from episode 13 !!! T-T tomorrow i shall watch the last and final episode !
# tokenising: Happy birthday gay , see you Monday . IMMA FUCKING JUMP ON YOU OKAY ! Have a good day my love , love you lots @_SophieeWhite_
# tokenising: @SegmentNext I got an xbox one on the 7th of April this year and it looks good for zombie games
# tokenising: @CheleReamey @funder @ZeldaShagnasty @FBI @TheJusticeDept yes I know but Comey should be pressured for further explanation about letter .
# tokenising: @MedievalBex Oh ! Wow ! I must see it then ... Daniel Radcliffe is not one of my fave actors , but this may help me overcome my aversion ... : D x
# tokenising: Conor McGregor backed up the talk and won interim gold with 2nd Round TKO . http ://t . co/XAadtJ8IUV http ://t . co/wP5juh3vQB
# tokenising: @RichardDawkins  Just like Christians with their bible , Americans are cherry picking the 2nd amendment .  #gunsense
# tokenising: Shout out to @ZombeaversMovie for being the worst movie since @SharknadoSyfy ... Sharknado has a chance to reclaim the title tomorrow ...
# tokenising: The most conclusive argument against the bleeding hearts and why logic doesn ' t hold for them in Yakub ' s hanging . https ://t . co/RrlAj1K9aN
# tokenising: was it liam payne or david beckham on the video we may never know #DragMeDownMusicVideoisOut http ://t . co/UKD2vSzwEz
# tokenising: That @SportsCenter ride along with Les Miles was the most awkward piece of television ever . 2nd place is this HELLO piece .
# tokenising: @moosehickey @megynkelly fake emotions & attitude ? You ' re making things up .
# tokenising: Im so sad in class i was like " im seeing Taylor SWIFT tomorrow !" and everyone was like " i fucking hate her she ' s so fake and ugly "
# tokenising: Megavideo is being SUCH a little bitch tonight . I don ' t understand it . Ugh . I just want to watch the last episode of Merlin , kay
# tokenising: @Jacknonce Sorry , the blacks I know are actually great , successful people . They aren ' t taken in by Dems BS . They are very smart , educated !
# tokenising: FLYING out to HOU Monday for the Jets-Texans Pre season MNF game ! \"" CANT WAIT\"" #FLIGHTBOYS
# tokenising: Matt Flynn May Never Play Quarterback for the Seattle Seahawks - Bleacher Report : Bleacher Report ... http ://t . co/8HuFaY8L #seahawks #nfl
# tokenising: Us Magazine Kanye West Has the Best Time at 2015 VMAs , Dances to The Weeknd ' s " Can ' t Feel ... http ://t . co/YgtKeStAEJ #news #May #Omg #NFB
# tokenising: @aalsi_aadmi @Sab_mile_Hue you must also do some learning in Islam and you may get content to your reason and logic .
# tokenising: waww ,, I wanna have it RT @ElmiraGriswold3 @Vah_Raflatahugs wow , ipad got just today free lol www . burna . in/fgye
# tokenising: Estimated 5% of Muslims in Britain r Islamists , Not many u may think , But there r about 6 , 000 , 000 Muslims in Britain . That ' s 300 , 000 Islamists
# tokenising: Rumourz -Tribute to Fleetwood Mac , Saturday , August 29 , LIVE on the Historic Palace Theatre Lockport Stage ! http ://t . co/C7OTukOB6c
# tokenising: Had a pretty good night . Jogging on the beach , swimming in my clothes . Popcorn and Family Guy . Excellent . : 3
# tokenising: @AudTheGing little , it goes on Netflix on October 5th I think !!!
# tokenising: @alias8818 Hey there ! We ' re excited to have you as part of the T-Mobile family ! Our inventory may vary from channel to channel . If ... 1/3
# tokenising: We ' ve just sampled some of Greg ' s DELICIOUS pretzels for our German themed boardroom dinner tomorrow ! Yummy !
# tokenising: Excited for the 5th album and Zayn ' s album #MTVHottest One Direction
# tokenising: @ShawnOnTheNBA We did .  He says it should be corrected tomorrow .  Thor is available on Twitter @ThoreosNmilk
# tokenising: Magic Mike XXL .... wellll boyyyyyy .... it was way better than the 1st
# tokenising: I pity those ' Ba turenci ' northerners . Many of them may be victims in this war against Boko Haram just as we get ... http ://t . co/BT2EYBjJJ0
# tokenising: Pillar of the #Chappaqua community an outcast after backing Trump https ://t . co/riZfmGh3rl Petty libs#tcot #uniteblue #Clinton #ows #tlot
# tokenising: RT : @thecyclr Its Friday people !!! Get that Kermit the frog cycling feelin ;) http ://t . co/1eN066lh // And i ' ve started holidays !! :))
# tokenising: Who are the dumb asses who decided to shutdown Main St on a Friday for a town of 50 , 000+ for a Strawberry Festival
# tokenising: How the Electoral College always has protected white power , from slave states to whose vote counts https ://t . co/BddF2RIZli #ElectoralCollege
# tokenising: Nicki ' s pastor is mad af right now . And it ' s Sunday smh
# tokenising: @Ryan_Debono But California Gurls , Teenage Dream , Firework , E . T , Last Friday Night and Part Of Me were Number 1 , Katy broke the record !! : D
# tokenising: @nytimes And in good news tonight , Fidel Castro assumed room temperature . Now we just need his brother and Maduro to follow . Quickly .
# tokenising: I have heard it said that the 2nd G in Snoop Dogg represents extra gangsterishness , for how else do you explain this particular redundancy ?
# tokenising: @BobPhillyPa @jennajameson its not about liberals or conservatives . Im neither and couldnt care about either . Its about basic human decency .
# tokenising: They made a sky zone here in Covina across the street from the AMC . I ' m definitely going sunday !(: who ' s down ?
# tokenising: Centre suffering from ' policy paralysis ', alleges Jayalalithaa : Jayalalithaa on Tuesday charged the UPA governme ... http ://t . co/FKTzJL5G
# tokenising: @CFhiker Hi Chris , Windows 10 is released in phases , If you want to upgrade now , you may refer to instructions : http ://t . co/2lNHid9jUz ^SJ
# tokenising: Expert analysis on the new Iron Maiden song after my 25th play-through :  I like it .
# tokenising: The farther left dems go , the more they will lose . Americans r on to their victim/identity game . #MAGA https ://t . co/sQPIIfOBIU
# tokenising: @utahjazz @gordonhayward @George_Hill3 Escape from a long tunnel🙌Today ' s victory is the best👍👍👍Expect victory in… https ://t . co/Ab2YPZC15H
# tokenising: Angela Merkel is a true leader . She has to tell a 14yr girl she cant have everyone stay in Germany http ://t . co/KRiuHppCiH
# tokenising: #GilmoreGirlsTop4  1 . Sukie2 . Luke3 . Kurk4 . Jess I can ' t wait for the new series to start ! 😍✨🎉
# tokenising: @Ed001andonly same way as in Bolton are being stubborn and not talking or demanding a stupid fee ? Are you expecting Jim to sign today ?
# tokenising: Kanye West may be running for president but that doesn ' t change the fact his wife has been pissed on my Ray J
# tokenising: Let me be the 1st to say it ... you people are about to be all over this Weeknd album . Especially the Dark Times song w/ Ed Sheeran
# tokenising: @sineadbleu well Lexus is taking us all to six flags next Sunday so I had to do it now so I could go on over there lol
# tokenising: @RiRiBB17 the only thing you will hear tomorrow is " all Big Brother 17 contestants have died of food poisoning
# tokenising: @Regrann from @ckarlos_sevilla - 🍑Shake your Bon-bon 🍑  @ricky_martin #rickymartin #onewor… https ://t . co/FXuvAu6Mgs https ://t . co/V5XlV7NULG
# tokenising: @nicki_belles @Siggy116 @Jgrizam22 @bryantbreck I like the attitude Nicki . I ' m gonna do it tomorrow . If I figure out how to do it lol
# tokenising: @chrisbrown Hey Christopher , would you mind going to Florida , between the 21st of august to the 4th of September .... thanks <3
# tokenising: En route back to Turin after a perfect day out in Milan . Looking forward to a chilled day tomorrow and the #U2 gig tomorrow night . #U2ieTour
# tokenising: Shawn with little kids may just be the cutest thing on the face of this planet http ://t . co/yl69jKxKEU
# tokenising: @NTANewsNow the death of our dear President Umar M . Yar Adua brought us GEJ , a disaster which brought about Boko Haram https ://t . co/j9Bb6P4wV7
# tokenising: @TimesOfIndia btw how much money you charged from " eminent people " to make Yakub ' s headline a prominent one ??? https ://t . co/z586zvUrsA
# tokenising: @KelseysPajamas For sure ! Tuesday noon ET live on UND . com ... #Irish and Nebraska ... I know you ' ll be tuned in !
# tokenising: What I love most about this is that every hag will be on DCUM tomorrow talking a t how trashy Nicki or Bey is . When clearly ...#VMAs
# tokenising: @kp_85 @YesImprovisers @MotorolaIndia enjoy the vibes with Moto G ( 3rd Gen .) #MotoBffRevealed http ://t . co/zjeNPFx1Sw
# tokenising: I ' m so mad Seth Rollins is going to talk so much tomorrow on raw kiwi fuck I ' m so mad
# tokenising: I think I got a date with my boo Irene tonight ... ima have to change her name to Hercules she so strong ... lol
# tokenising: @PacificaPatch This Friday night , Terra Nova football is playing one of our teams up here . I can do a little something for PP if you want .
# tokenising: An octogenarian Motilal Vora with his droop and hunchback walking behind Rahul Gandhi may be a disgusting sight for some , but it pays .
# tokenising: It ' s Monday Night Football Wrangler Nation !  Game time 7 : 05pm vs . the Wichita Wild !  Get your tickets now to cheer ... http ://t . co/ZNiOvK7o
# tokenising: Heath Ledger in Batman may be the best performance of any actor in any movie of all time
# tokenising: Carvel Ice Cream is celebrating National Ice Cream Day , Sunday , July 19 , with buy one , get one soft serve ones .... http ://t . co/waAvWSE9dX
# tokenising: Yesterday was #NationalFastFoodDay and today is TAYLOR DAY !! Coincidence ? I don ' t think so . 🤗🌮🍟🍔🍕 https ://t . co/D4J31d5N4i
# tokenising: What is chilling ? I get more stick from Muslims than I ever do from non-Muslims - am sorry it is the truth world - as much as it may pain
# tokenising: @da_minicooper and if I still don ' t have a boo by Valentines then I ' m blaming you
# tokenising: Italian police stopped California rapper Snoop Dogg on Friday as he prepared to board a private plane bound for ... http ://t . co/DH38uKpUZI
# tokenising: Google Earth now available in VR https ://t . co/AtowhL7iZV #internet #feedly
# tokenising: I was in like the 4th , 5th , 6th grade burning CDs and mixtapes that faithfully consisted of Dipset , old Bone Thugs , and hella Jay-Z
# tokenising: Thursday I was at Eric Church , last night I was at OAR , tonight I ' m in my pajamas already watching Cars . Rock star life .
# tokenising: @SMShow  Donald Trump will tilt the planet away from the sun . It ' ll be marvelous and you ' re gonna love it .
# tokenising: Google+ can enhance your position in Search &amp ; connect you with NEW prospects ! Interested ? http ://t . co/a8ipboHLpO Workshop Derby 18 August
# tokenising: And if my day wasn ' t bad enough already , Snoop Dogg just cancelled his concert tomorrow night ....
# tokenising: Wish I am now in Japan to feel the Naruto mood and watch #BorutoTheMovie . Malaysia November baru nak keluaq
# tokenising: @CassieLeuffen Chuck Norris and 10 , 000 people march through downtown Birmingham Saturday and @OANN doesn ' t cover it ? Who dropped the ball ?
# tokenising: MTSU just beat WKU 34-29 . The Sun Belt is really starting to get interesting . Have to take care of business on Saturday ! #PackAttack
# tokenising: The fact that there is a 3rd Sharknado is everything that is wrong with this world ...   Lamer than my #LameJoke collection ...   #Sharknado3
# tokenising: Calibraska , the top album Friday on iTunes -ahead of major-label acts like Future , Jill Scott , Rihanna , and ... http ://t . co/gTaqw6kuPa
# tokenising: I seriously may be the only person who doesn ' t like Madonna
# tokenising: Buhari has shifted his campaign promise on Boko Haram . Now claims he will end BH by December instead of 2months . Nigerians have been scammed
# tokenising: @hunkerdad @Liz_Cheney If the election were held tomorrow , I ' d only vote for Bernie Sanders .
# tokenising: One of my new favorite shows is #ThisIsUs and our very own @canuck4liberty does awesome ep recaps !!!
# tokenising: Holy mother of all that is good , Kanye West ' s speech at the Video Music Awards on Sunday was all sorts of burning ... http ://t . co/wU8wPOosac
# tokenising: @RichardDawkins @AdorableMammal Interesting enough why is it Islam is the one culture/ religion 3rd wave feminism refuses to criticize ?
# tokenising: @talinaroma Harry Potter , Percy Jackson , Thursday Next , Game of Thrones , or Pillars of the Earth are mine . #SS15
# tokenising: ' Don ' t go there !' Palliative Care Specialists warn Victorian Premier - HOPE : No Euthanasia https ://t . co/fd0bPKI1sT #springst
# tokenising: @goldsborohall Haha its like Big Brother watching . Sorry we didn ' t see you , what a fantastic wedding saturday was though . Catch up soon .
# tokenising: I narrowed it down to a top 3 of : 3rd : Rumors by Fleetwood Mac 2nd : The Libertines by The Libertines ( funny enough )
# tokenising: My mom and I sat in the bathroom all night jamming nirvana and painting our nails &amp ; just talking . Probably the best night I ' ve had in awhile
# tokenising: If frank ocean doesn ' t realize his album by July 45 I ' m going to kill myself
# tokenising: If you ' re against animal testing then you ' re against animal testing ALWAYS - not until MAC release a really nice colour lipstick lol
# tokenising: Paul McCartney playing as the sun sets in Chicago was definitely one of the most beautiful things I ' ve ever witnessed ok
# tokenising: #nw B2ST ' s 3rd anniversary live stream with subs yay~
# tokenising: Sundays vlog is processing , Monday ' s is exporting ... You know for having to do it all on a iPad is say I ' m doing pretty good .
# tokenising: Well with Zayn joining ISIS it is hard to maintain their family friendly image . https ://t . co/ObzEtFCpPg
# tokenising: Windows 10 may be installed on 75 million PCs , but how many of those rolled back to their previous version , like me ? Suck it , Microsoft .
# tokenising: It ' s Wake up Wednesday at Cambridge !  Stop by the Clubhouse for Dunkin ' Donuts and juice .
# tokenising: Came 6 hours before the Ed Sheeran concert began , i waited in the hot sun and almost passed out with barely any water . But it was so worth it
# tokenising: Amazing !! We may not have won the 2nd game , but it was hard fought & the sold out BCA was rockin ! #PROUDTOBEATIGER :) http ://t . co/NfgZ7Otf
# tokenising: @NicoletteKelley Set a reminder : October 6 . Get ready to join the celebration around #AllDayBreakfast , Nicki !
# tokenising: The utterly brilliant @langfordrussell #Bromley do the #MannequinChallenge , all for @BBCCiN https ://t . co/JddLaxIhHT
# tokenising: @realrominarey Way to go .  I dropped my ballot marked OBAMA off on Wednesday in Colorado , gives you a good feeling .  I hope CO goes OBAMA .
# tokenising: The ONE time we want to use the Amazon Prime streaming and it ' s down ... grrr ruined my Sunday night ! @AmazonUK
# tokenising: Google Earth VR is amazing it reminded me of an early version of a computer game . The model  of the Tempietto is ... https ://t . co/3LoLXHu3d0
# tokenising: I don ' t ever Skate Etnies , but Ryan Sheckler 7 ' s the Marana is Too Sicc ! As Soon as it Comes Out in November I ' m Buying a Pair :-)
# tokenising: Dustin Johnson just can ' t do Sunday ' s
# tokenising: Okay wait before I go everyone listen to the version of last Friday night by Katy Perry with Missy Elliot . It ' s gold . Thank me later .
# tokenising: @LumiaUS The 1520 is the first Nokia I have ever had break on me . 1st . the phone stops reading the micro sim card http ://t . co/bPtuUmwJmd
# tokenising: RT @Youngcules : Nolito with an assist and a superb winner for Benfica against Arsenal last night . He really is turning on the heat !
# tokenising: Jay Z ' pays tribute to Michael Jackson as he joins Instagram ' with touching photo , it may be his last http ://t . co/dQHJT59Ciy
# tokenising: @GeorgiaLogCabin she needs to be convicted first . Will Obama pardon Trump for his Cuba embargo fiasco ?
# tokenising: @jimbobohan @burko77_ I certainly wouldn ' t be spending my hard earnt  taking the kids to see say Shels 2nd XI v us , clubs will fold no doubt
# tokenising: @cwbatb @beourguest @celinedion a reunion is expected . plz sing the theme song #Beautyandthebeast
# tokenising: @topcity yep .  Once it ' s lost , it can never be returned .  I was in Constitution Hall last Fri .  Got chills .  So much history was almost lost
# tokenising: Any evil twins you may have won ' t be able to break Windows 10 ' s facial recognition security . So that ' s reassuring . http ://t . co/6bUshfnfen
# tokenising: George ' s stories may be my favorite thing about Seinfeld - he is so passionate it ' s wonderful
# tokenising: I will be back on PSN tomorrow the 2nd of september with my new PS4 :) message me if your intersented in my psn name :)))))
# tokenising: Wichita St . with fundamental breakdowns in 8th . Hall singles , Harbutz fails to bunt him over . Hall picked off . Coy whiffs . SIU lead is 4-3
# tokenising: Fabio Capello : \"" From what I ' ve seen these days I can assure you Russia are capable of getting a good result vs Portugal tomorrow\"". #cantwait
# tokenising: Looks like the first shoe ( or boot ) may have dropped ... Rick Perry stops paying all staff as fundraising dries up http ://t . co/w4pShn4Wup
# tokenising: I liked a @YouTube video http ://t . co/mjPn11l11g Foo Fighters , Aurora , Live , Milton Keynes Bowl , from the front , Saturday 5th
# tokenising: @DrHLecterMD @lecters_imago / You portray Hannibal beautifully may I just say .
# tokenising: A no no , Kanye announces he ' s running for president , and nicki gets crazy with Miley all in the the same night .. It ' s Sunday wtf
# tokenising: .@HillaryClinton Visit us for #SmallBizSaturday and pick up our 1st #stillwithher tee unveiled at 12am !    🙌💋 https ://t . co/XOAm8x6iRn
# tokenising: @realtrinamcgee @DTPERKINS23 so glad they are bringing Angela back . this makes me happy I just hope Shawn and Angela get their 2nd chance
# tokenising: I will end the embargo against Cuba .
# tokenising: I may have to record MOTD2 tonight to watch Inbetweeners Top 10 moments with Martin . :)
# tokenising: *A hot cup of coffee on a cold morning & some nice country music to go gets me everytime :)! #WeAreND ( 8-0 ), 3rd in the BCS !
# tokenising: Anyone watch #ThisIsUs ? Pretty cool show with Mandy Moore and Milo Ventimiglia in it .
# tokenising: All these talkatives sef ....  Shey you don clear your sef from the Boko Haram mess ?  Aproko https ://t . co/OiYP5ZPFca
# tokenising: The The Orlando #Python User Group meetup is hosting the Deep Learning with #Python on Monday after next . Be there : https ://t . co/2oKwHKAOrL
# tokenising: If you are one of the many shoppers out there wanting to take advantage of Amazon Prime Day today July 15 -... http ://t . co/hbQaLKwDzV
# tokenising: NO14 - DEN 34 ; Peyton and Eli may meet in the Super Bowl if both Denver and the New York Giants keep winning like they did Sunday
# tokenising: Just one more day to go -&gt ;&gt ; Madonna ' s Rebel Heart Tour starts tomorrow . What to expect ?! http ://t . co/OXCAc47pTi
# tokenising: Rum Chata hot chocolate , Thin Mints , and Netflix . This is how you do Saturday night . http ://t . co/wnN1lV3r
# tokenising: @gigagiga333 @Smallnobody John Cena may have put his dick in Amy Schumer . He loses what little anything he had for that .
# tokenising: Tomorrow we are taking over the Wenonah vs . Midfield game with T-Mobile ! #TMobileFNLBham
# tokenising: When you realize you ' re going to see Ed Sheeran tomorrow @annaleseallison http ://t . co/g35qrJEWLC
# tokenising: Michael from Good Times is the 2nd greatest Michael . Michael Jackson is number one .
# tokenising: Can ' t decide if I ' m more pumped about the crowning of a new Miss USA tonight or the All-Star game on Tuesday
# tokenising: Tomorrow is National Hot Dog Day and @7eleven will have $1 Big Bites !  Get you a wiener !  #NationalHotDogDay #BigBite #7Eleven #wieners
# tokenising: @IreneNell Good morning Irene :) I love the tiger photies so much ! Do you own them ?
# tokenising: We ' ve gone from a country that voted UKIP into 3rd place for total votes , the party looking to seriously cut the amount of people coming in
# tokenising: Tonights Friday Family Movie Night is Journey 2 , the Mysterious Island ! Looks promising !
# tokenising: This month is going to be amazing .  4th I see Courtney ! 9th Stacy moves back !(:  17th My Birthday !!(:  Then it ' s thanksgiving and no school !
# tokenising: Boruto : Naruto the Movie ' s September 9 Philippine Premiere Revealed !  Film will open exclusively in SM Cinemas .... http ://t . co/pEL20MRdMv
# tokenising: @Ramzwi @LeutrimRexhaj If you ' re struggling come January and Benzema don ' t happen , I ' d go for him , he ' ll give 110% for Arsenal , and score !
# tokenising: @michaeldickson sicko is too kind . These are depraved murderous thugs acting out the education they received from #Fatah and #Hamas
# tokenising: The radical left positioned Trump as a Nazi when they themselves r deeply anti Semitic and their riots are mini Intifadas . Keith Ellison .
# tokenising: @scooniepenn and pro dt because they knew Putin could manipulate him
# tokenising: Federer advances into fourth round at US Open : In the blazing New York sun , Federer seems to be in his element ... http ://t . co/CoiDuhKlL4
# tokenising: Finally going to see ANT-MAN tonight , then off to see ROGUE NATION either tomorrow or Sunday . Looking forward to both .
# tokenising: Psych and garage rock fans will love @THEVACANTLOTS @LovelyBadTweets & @__cosmonauts__  at the Echo on Nov 6th ! Tix http ://t . co/Kh7ZPEqE
# tokenising: 26 August Free Kids Minecraft App Building : Creating web apps about Minecraft ! http ://t . co/uOZdIkVrHv http ://t . co/oPa0j6eJHM
# tokenising: @jimmyfallon #GilmoreGirlsTop4 easy https ://t . co/Y7A9snVhxr 2 . Sookie 3 . Emily 4 . Luke
# tokenising: Happy Monday everyone .  I hope the week is off to a good start across the board . Here ' s a Thor sketch by Mike . #art https ://t . co/LrD92nHgn6
# tokenising: Zayn is a fucking psychic he ' s like THE MAN  https ://t . co/xrCNN1aGCT
# tokenising: @BuddyDogHS @Rich2011storm saw your post ; just sent you some donations via Amazon that should be arriving Thursday . Keep up your good work !!
# tokenising: After the Samsung press conference on Friday , I ' m inspired to buy a Galaxy Note 4 when the price drops to clear old inventory :)
# tokenising: @morningmika Your morning show is the one thing on any NBC outlet that is worth watching . May God always bless Sarah Palin and her family !
# tokenising: Mort Zuckerman I can just change who I am plenty of , not to mention all I may give is in fact all my love . http ://t . co/XqMBqhme
# tokenising: @jaymohr37 Mr . Monday night just made my Thursday night '!! @rvd #mohrstories
# tokenising: NEWS : Christian Media in Nigeria : Yolanda Adams and Common singing " Glory " at the BET ' s #ThankYouObama event by… https ://t . co/hVCpEFJf8x
# tokenising: @cdvargas2 it ' s called Hillary was a criminal and tried to rig the election . The dems didn ' t vote as a protest .
# tokenising: @YoginiJane while the met may not be perfect why don ' t you piss off to somewhere like Mexico City if you don ' t like it !!?? #tottenham
# tokenising: Deeply saddened by the sudden death of Frank Gifford . He will always be the voice of Monday Night Football for me .
# tokenising: @mongbow Happy birthday for tomorrow ! May you get the naked Seth Rollins you ' ve always wanted ;)
# tokenising: Nike didn ' t have what I needed so now I need to order it online AND I NEED IT TOMORROW IHML
# tokenising: @chaddockr @LexStarwalker Your conversation on race/species in the #CypherSystem gave me much to think about . I may make a post on Google+.
# tokenising: After S6 , my #GilmoreGirlsTop4 has changed : 4 . Richard3 . Sookie2 . Jackson1 .  Paris
# tokenising: Are they closing all schools 4 the Pope visit or the Million man march anniversary ???? Foolishness . ...
# tokenising: Today I found nirvana , and all it took was kayaking with my best friend behind me , my favorite jam , a fucking bagel , &amp ; the sun beaming on me
# tokenising: Ooh national girlfriend day on Saturday and there ' s a fan screening of Paper Towns , what a lucky coincidence
# tokenising: It is not about Tsipras , any more . It is about how the 3rd MoU will be implemented . Get over him ... https ://t . co/UcpQpK235Z
# tokenising: #Turkey #Yemen Passenger trains collide in Iran , at least 40 killed+Videos https ://t . co/4enuuxkX2K https ://t . co/ClqCgSJqzS
# tokenising: @realDonaldTrump In a roomful of Adolfs be a Ruth #ruthgruber #nytimes #TrumpTransitionTeam #SundayMorning
# tokenising: With that sweep of the Royals . White Sox  are now 3 games closer to 1st place !#WhiteSox #MLB
# tokenising: @humelton Legal terminology for opposing gay marriage ? Homo MatrimOHNO
# tokenising: I ' m really bored guys idk if you can tell I ' m gonna have a Netflix marathon tomorrow suggest things I could watch
# tokenising: Watching David Letterman with no audience but playing like they are still there is the 2nd most brilliant thing I ' ve seen tonight .
# tokenising: Drop 75% Price : £7 . 88 . Paperback : The Gay & Lesbian Marriage & Family Reader : Analyses of Problems and Prospe ... https ://t . co/7tdFYTrUui
# tokenising: Life is a Climb , but The View is Great . #ThankYouObama
# tokenising: happily living my love life with Muhammad Ali on every 13th
# tokenising: @DritaDavanzo you know I exist ! Yay ! I ' m a big fan and so excited to watch Mob Wives in Jan ! :)
# tokenising: Listening to Bad Blood on the radio 1st time : this is awful 8 : people like this ? 15 : that bass line isn ' t so bad  Now : NOW WE GOT BAD BLOOD
# tokenising: @MarieDJones Think Sharknado is on Netflix . While being a veggie today I may look for it . :)
# tokenising: I ' m going to see Paper Towns tomorrow finally ! AYYEE
# tokenising: When all the poor whites who voted for Trump get their Medicaid taken from them I ' ma be like ¯\_( ツ ) _/¯
# tokenising: Ian McEwan on Charlie Hebdo - facing down hatred with laughter https ://t . co/EYmTTzmndJ via https ://t . co/wVf2HHCq6z
# tokenising: #BritishBuddhu if Rahul Gandhi is really a British Citizen , I ' m very concerned about the comedians out there . They may be without jobs
# tokenising: FUCK BOB DYLAN
# tokenising: Wicket , its getting worse for the Afghans , they have slipped to 22-4 after Karim Sadiq ( 5 ) was run out by Jos Buttler in the 6th over .
# tokenising: @_MCDialogue_  MIsrepresentation . What was said was that a lot of Christians may not have full understanding of the Trinitarian confession .
# tokenising: You can make jokes about killing kids in drone strikes but non consensual sex jokes are off limits
# tokenising: It is scary that Kris Bryant is the 4th best hitter on the cubs ..
# tokenising: articlesection classpagepAndroid Wear may be very close to working with iOS
# tokenising: I managed to find Nintendo in Google Earth VR . How many nerd points do I get ? #alwayssunnyingoogleearthvr
# tokenising: You may hear how a liberal protester was attacked at a Scott Walker rally in Iowa . It was planned and someone sent me the evidence .
# tokenising: Can ' t wait for #RAW tomorrow ! Brock Lesnar and Undertaker in the same arena ?!? #WWE http ://t . co/ZZnmYIZUkp
# tokenising: @justinbieber please Justin follow me ? Hope everyday ! Je t ' aime ! Can wait to see u in Paris for the 1st time ! Je t ' aime <3
# tokenising: @storm_girl83 Gary Ablett polled 2nd or 3rd & his team finished last . Not all about the team . Jobe has improved & grown so much over the yrs
# tokenising: Hey @NFL , start worrying a little less about Tom Brady and start punishing actual criminals  https ://t . co/ZhiaCcubk1
# tokenising: Possible to critique leaders/countries/policies/etc x AND y ; not mutually exclusive - White liberals that can only be found critiquing x .
# tokenising: @krl_brndn @BosnjoBoy @deSyracuse the only one in town to have fought #ISIS *in that region* is #FSA . Assad regime strike only helps Daesh
# tokenising: BOOM ! A Ryan Braun grand slam puts the #Brewers up 6-0 in the bottom of the 5th ! #MILvsPHI
# tokenising: Looks like Rick Perry may be the first out in the #GOP race .  He ' s out of money already !
# tokenising: In bed in Plymouth hotel for the last night of holidays - home tomorrow . Had fun meeting @TomDaley1994 and @toniacouch but time for home :(
# tokenising: Looks like @Microsoft may still be in the handset/smartphone business !  #SurfacePhone #Windows10 http ://t . co/SubGXXMqlz
# tokenising: H&M delivery is SO shit . I ordered things and paid extra for next day delivery on Saturday and it still hasn ' t come
# tokenising: A Monday without teen wolf is a Monday with less stress and anxiety
# tokenising: Happy #thanksgiving to @utahjazz Grateful for team ' s hard work and great win last night #GoJazz   #TakeNote
# tokenising: Win tickets to see Janet Jackson at the Air Canada Centre on September 15th ! http ://t . co/CJwcfgDjuL
# tokenising: The Gucci hijab bye I ' m crying but she looks stunning https ://t . co/dMrvvpVRcP
# tokenising: Caitlyn Jenner may be responsible for the death of Jon Benet Ramsey ( and someone else ) http ://t . co/KxfO3j6snM via @SFGate #LGBT
# tokenising: we ' re Sophia grace and rosie ! Can ' t wait to see you on Ellen tomorrow ! xxx  @TheEllenShow @PrincessSGB @PrincessRGM http ://t . co/abvxnWQB
# tokenising: Florist’s free speech : Comparison to Melania Trump is a false equivalency https ://t . co/Ryf5rpJrKy
# tokenising: @iM_Lowie dam . cant wait to get back . i come home tomorrow night , but leave the next day for elon university in NC
# tokenising: @butt3r I ' m with you on Mass Effect 3 . Thats GOTY for me so far . Still waiting on my other two , but one may be Persona 4 Arena .
# tokenising: Holy shit National hot dog day is Thursday . If you know me well enough you ' ll know how important this is to me rn
# tokenising: @LaszloBock2718 congrats on the book , invites to add value from HR . Any thoughts you may share about internal communications in Google ?
# tokenising: It ' s a sunny SausageFest Saturday afternoon but if we are going 2 make it 2 church on time it ' s time to slow up the pace ! Eric Church 2night
# tokenising: @FoxNews want to give him the death penalty ,  let him die in jail
# tokenising: @MissEWray September is a great birthday month ! Same with me . Great to see your name at Harry Potter today too !
# tokenising: Loving the opening debates rap game Kathy Crowley October 20 - Bruno Mars http ://t . co/jyQ3lqbU
# tokenising: Give me 5 mins with Candy the dancer from Deja Vu I ' m nutting on my 4th pump she that bad lol
# tokenising: Cats eating bodies in east Aleppo as they run out of space for the dead via @DailyStarLeb  https ://t . co/CifxiMFfOl
# tokenising: Winding down the Sunday with Bob Marley on #vinyl . http ://t . co/8fWRakgeCp
# tokenising: saving episode 12 for tomorrow because she made me angry and i just spent 13 hours playing naruto ultimate ninja 4 so my eyes are dead
# tokenising: If distributions are not large enough , the IRA owner may have to pay a 50% penalty on amounts not distributed https ://t . co/pTCvyUOHdw
# tokenising: Marley Monday at Reggae Central ... 20% off all Bob Marley merchandise today with code word " BMW ."
# tokenising: I don ' t really know when I started to be interested with U2 ' s music , but I can say that Original Of The Species was the 1st U2 song I liked .
# tokenising: Slowly getting my last bits pulled together for Barca ! Gonna get everything finalised today so I can just relax tomorrow :)
# tokenising: @SurlyNurseJoy New Iron Maiden album on the 4th of September~ Has their longest eversong on it , which is why that reminded me .
# tokenising: Watching Ghost Rider : Spirit of Vengeance . It ' s much worse when you may have thought . #fb
# tokenising: Minecraft account : Derosion @Mineplex Retweeted , may I wish best to all for the legend rank !
# tokenising: Anonymous to Wikileaks : We ' re more interested in transparent govts & bringing out info they want to hide from public .   http ://t . co/m7ca9SOa
# tokenising: I ' ll set my DVR to record the encore so I can watch Nicki ' s performance tomorrow .
# tokenising: @mandikaye FYI , my other favorite book in that series is the 4th . Oracle ' s Moon . The beginning hits me SO HARD every time .
# tokenising: I ' m still dying over the fact Fourth of July by Fall Out Boy was in Paper Towns omg
# tokenising: Obama is disrespectful & saddening Obama does what Dems FEAR Trump may do https ://t . co/KRsItmuXw3
# tokenising: Monster jam tonight and Celtics home opener tomorrow ... loveeee living walking distance from the gahhhhden #bostongirl #citychick
# tokenising: Jurassic World will be rerelease to theaters in IMAX on August 18th oh . can you withdraw the money automatically or ???
# tokenising: Samsung may soon be launching a revolutionary new device - the Galaxy Note 5 #FMEA edition - http ://t . co/3Wpgpolp1K
# tokenising: Axl Rose needs to just give up . Now . Not later , not soon , not tomorrow . NOW !
# tokenising: Palace in talks with Dortmund player , Bolasie on the move and Zlatan has a warning for potential suitors ... http ://t . co/aBlAk15ikk
# tokenising: Holy crap !  watched @JohnCena ' s promo when signing the contract to face Seth Rollins . WOW ! " This Sunday , I ' m gonna make you mine " ( bitch )
# tokenising: #ThankYouObama for creating the strongest @republicanparty in almost a century and electing @realDonaldTrump .
# tokenising: Rolling Stone and The Zone are the best songs on Thursday
# tokenising: So Adrian nearly has as many fantasy points for my team as David Price does . 35 for Adrian , 42 . 5 for Price .   Still only the 7th . #Rangers
# tokenising: #ThisIsUs The freedom movement is going strong and sweeping the whole world .🌎Next stop : FRANCE 🇫🇷#MarineLePen  https ://t . co/cKPqQWNIl7
# tokenising: Seeing Frank Ocean in two days , is literally the one and only thing on my mind , until 10 : 45 p . m ., Saturday night .
# tokenising: @EleanorJCalder Hello , Eleanor . Will you please follow my account @beacaresosa for my birthday on the 14th ? please , you won ' t regret it .
# tokenising: Dustin Johnson has a great chance to win the @PGAChampionship as long as there is no Sunday round . @DJohnsonPGA
# tokenising: Hate a Ben Carson/David Clarke ass nigga . The most detrimental type of people to black culture .
# tokenising: I guess Knicks/Heat is on for now . Pretty clear that tomorrow ' s game wasn ' t going to happen .
# tokenising: @Ibn_M_ All you need to do is catch U2 to Brunel University looool in shaa Allah man , I ' m free atm . I start in October
# tokenising: if anyone is going to dunkin tomorrow morning and is just feelin real generous my order is a medium chips ahoy iced coffee w cream&amp ; sugar :-)
# tokenising: @klgandhoda Prayers for all of you today . May God carry each one of you during this sad time " Footprints in the Sand ",  RIP Frank Gifford
# tokenising: Reasons to Celebrate :  Forcing the turnovers : The game Sunday between the New York Giants and ... http ://t . co/4zqe5Tn6 #nfl #nyg #giants
# tokenising: Thinking about going tonight Church tonight . Everybody is invited . Ladies free all night with a Bible lol
# tokenising: It would be a strategic mistake of the 1st order 4 Tsipras ( let alone a genuine anti-austerity politician ) to seek and maintain a leading ..
# tokenising: Melania , unmuted : Melania Trump gave a speech using her own words , which  reminded us why women can’t relate to her  https ://t . co/rMRAkqfYmX
# tokenising: Galaxy Note 5 may have the great selfie camera of the S6 http ://t . co/r65InJYOVJ #Smartphones
# tokenising: Got some great shots of the March Fourth Marching Band tonight at Americaplatz @Musikfest , they were fantastic !!!!
# tokenising: Vic has a bias for action . He may need to do more work on strategy .   Inside the failure of Google+: http ://t . co/kp8Yzytd7B via @mashable
# tokenising: i just saw last monday night raw now and @JohnCena came and made Seth Rollins and the authority shut the hell up love it #nevergiveup #wwe
# tokenising: I can and will fight for #BlackLivesMatter . However , I am white . I never will be turned down for a job because of my skin tone . 4/?
# tokenising: Can we just haw class cancelled tomorrow ? Cause I really don ' t want to go to BCA 101 . I ' d rather eat worms ....
# tokenising: <--- New Icon . I may just be changing icons a lot as long as Jennette uploads pics cause she is just too beautiful
# tokenising: Nokia torch is still the best phone ever made ... It will fall from the 2nd floor and all u have to do is coy
# tokenising: One thing though : when they show Ice Cube wiring the script for FRIDAY ... that was inspiring as hell . A lot more tomorrow .
# tokenising: Sen . Bernie Sanders braves the summer heat at fairgrounds Thursday night http ://t . co/mdfSS7xYiD
# tokenising: @say_shannon Thank you ! And , yes , it ' s out on Feb 1st in time for Valentine ' s Day . For reasons .. :) :)
# tokenising: Why do people make such a big deal out of being alone on Valentine ' s day ? Look , you may not have a lover but theres chocolate
# tokenising: Jay-Z stole his whole 2nd verse from " 99 Problems " from Bun B in the UGK song " Touched ". Come on y ' all listen to old hip hop .
# tokenising: Melania Trump can copy Michelle Obamas speech word for word , but if I plagiarize on a research paper I ' ll get kicked out of my university 🙃
# tokenising: Quoting Tony Blair " All the hallmarks of Al Qaeda ." What , u know this within 2 hrs or less than 1st attack ? Wtf ?... https ://t . co/0xDt2A9gCm
# tokenising: Sat trying to #blog finally , and Fleetwood Mac comes on . Sign today is going to be a good day , and I ' m NOT missing out on the #Valpo sun ...
# tokenising: E L James ' writing caliber is that of a 2nd grader . Throw in some bondage though and you ' ve got a best seller
# tokenising: I ' m taking my death tomorrow , Kpop fans make me mad
# tokenising: The Latest : Ireland ' s Paul Dunne turns British Open into amateur hour with stunning 3rd round - 7 ...: Ireland ...  http ://t . co/UuNat7KBZW
# tokenising: Vice President Mike " Fag Punisher " Pence https ://t . co/GfqIIw7vEt
# tokenising: Downloading Naruto : The Last , I ' ll rewatch it tomorrow before class ^////^
# tokenising: soc sec & medicare & medicaid & HUD & food stamps will be gone ! 1/3 of America will starve to death , sick & homeless https ://t . co/LLebnlGGiX
# tokenising: I have to decide am I going to go to a Madonna concert on Saturday . Could be interesting . That ' s gotta be a 3-4 hour show , right ?
# tokenising: Amazon may be cooking up a $50 tablet The Internet giant is reportedly working on new Fire tablets for the ... http ://t . co/yRmqFq3PxN
# tokenising: Paul Dunne with a great quote post round on his thoughts on the 1st tee tomorrow leading the Open ... " Make contact ."
# tokenising: @Safeeyar yap . That ' s why i dont understand why they ' re making fun with messi ' s height . Do they expecting him to be a Jan Koller ? Lol
# tokenising: Today was the last day of Disneyland ' s regular Space Mountain .  As of this Friday , it will be Space Mountain Ghost Galaxy .
# tokenising: in 4th place :  Gay men and the battle to be happy | by @getstuart |  http ://t . co/Wtqv0q9A1T | http ://t . co/JrJJqVs3Y0
# tokenising: Just keep watching Brock Lesnar and Undertaker going at it on Monday . Absolutely brilliant ! That ' s what went missing in the " new era " #Brawl
# tokenising: We should start Ox on Saturday imo , he will terrorise Evra just like he did last season .
# tokenising: Whoever decided how Oracle does date arithmetic is getting kicked into the sun .
# tokenising: Internet of Tents and 3D printing workshops with @mr_koz ,@ajfisher , @geekscape and Andy Kitchen ! #buzzconf https ://t . co/tf0Vi2KcNL
# tokenising: omg i may have a chance to still go to the sam smith concert !
# tokenising: @WillingBlam Today ' s my 21st birthday and it would be awesome if I could get a birthday reply from Thor !
# tokenising: @nbauer10 yep AC/DC tonight at Ford Field then on a plane Thursday to San Diego ...
# tokenising: I notice several people having issues with SAM Broadcaster on #Windows10   May I suggest http ://t . co/zLrLoaIA82 it works great on Windows 10
# tokenising: @tajinderbagga No issues if he is saving an innocent of any religion , but Yakub killed hundreds of innocent , tomo Bhushan may back ISIS too !
# tokenising: RT @CGBlasi : Very impressed with Joco Teenage Republicans ! 16 teens showed up today , ready to #fight big government and Obama ! #NObama
# tokenising: @chrismcquarrie whats the secret between you and tom cruise making awesome movies ( ex jack reacher , edge of tomorrow , mi rogue nation )
# tokenising: That time Christina Crossin dropped Melania Trump speech during her set at the #INSCENE 2 year anniversary party ... https ://t . co/AbkE1RvWvk
# tokenising: Excited to be a part of the battle of Big Brother vs Little Brother tomorrow afternoon . Going to be fun . Call sheet is loaded and ready 2 go
# tokenising: #JummaMubarak to all Muslims , May Allah grant us a chance to offer jumu ' ah prayer in the shadow of Kaba ...!  http ://t . co/lxR0t7qTbr
# tokenising: Wow , Colin Powell going to CMU for MLK Jr . celebration in January . That ' s cool . A big name for little CMU .
# tokenising: @Daggy1 obama ' s goal is to lead us into 3rd world status , so you ' re absolutely right , \" obama doesn ' t care\"
# tokenising: @danisnotonfire Dont come to milan tomorrow i ' ll literally punch you in the face im already too stressed like this thanks
# tokenising: @BadAstronomer Trump is like #TheWalkingDead Negan , breaking people until they are willing to serve .
# tokenising: @Lumia #Lumia @Microsoft 2nd , you guys haven ' t released a lumia that has a QHD screen , or takes video in 2k resolution yet .
# tokenising: Reading The Hobbit , listening to Sam Smith , mom is cooking her mean Pork Nilaga . Steady Sunday it is . Good morning :)
# tokenising: The thought of the queue at Digi tomorrow is making me upset
# tokenising: Tomorrow is going to be my tenth time seeing Shawn perform , I ' m so lucky to be able to even once , this is so insane
# tokenising: YES we all know INDIO vs CV is tomorrow the BELL GAME . Its enough .!!
# tokenising: @BleuFootedNewby Ah woops that ' s my bad they play the Knicks tomorrow
# tokenising: Big Day in the sun now a Big Night in the heat with @tobybinge #poppinbottles
# tokenising: I ' m hooked on horse racing .. I ' ve been to the Del Mar Racetrack in San Diego .. and now I wanna go to the Kentucky Derby ..
# tokenising: @Periplus_Store on the 6th books : " Harry Potter and The Half Blood Prince " #PeriplusQuiz16
# tokenising: Waiting to see a photo of Steve Bannon where he doesn ' t look like he has the worst hangover of his life .
# tokenising: Morning all . Just woke up to Madonna on the radio with Borderline . Cool
# tokenising: Never underestimate the stupidity of Tory backbenchers .  Nor think that #Corbyn4Leader couldn ' t win in #GE2020 https ://t . co/P9DuOYzCzR
# tokenising: Hope to see you at our Social Media Week event in Glasgow tomorrow . http ://t . co/YNAgaYB8 #smwfilmcamp
# tokenising: Holla to all my bad hombres who decided to work today and get that money $$$ #blackgrinday
# tokenising: #HappyThanksgiving @tonyromo ! From your #Uber delivery driver you didn ' t tip on Thanksgiving ... Bless you sir .
# tokenising: Your #Saturday #Satisfaction with Madonna - Don ' t Cry For Me Argentina http ://t . co/CvHFOMO1tN #80smusic #top40
# tokenising: @1DInsideReport Thanks for another great show , Miss you tomorrow as I am going to Ed Sheeran !  Will catch up on your tl when I get home !
# tokenising: Sunday Supplement are honestly making out that Kane is one of the best strikers in the world .  He isn ' t even the best striker at Tottenham .
# tokenising: Yesterday is the day the atomic bomb in Japan .  I embarrassed as a Japanese , was a moment of silence for the first time .
# tokenising: Of course I ' m not home when my team in town  :/ \""@SteveyC16 : Knicks vs Celtics preseason game in Albany this saturday .... who going ??\""
# tokenising: @JohnLegere @TMobile I was two weeks early I traded my old note for a galaxy 7 wish I had the new vr gear . I love the first one
# tokenising: When you ' re about to not go to school to go see Justin .  https ://t . co/yv1iJ293Ay
# tokenising: Gandhi protested successfully never once resorting to violence . People today make me sick @#londonriots
# tokenising: Mark Martin ' s the 1st to crack 191 mph , and now leads a MWR 1-2 ( Bowyer 2nd ) and Toyota 1-2-3 ( Kyle 3rd ) after 36 cars . #NASCAR
# tokenising: My 2nd favorite in the Brazilian NT and sa Chelsea pd . Happy Birthday @oscar8 : D And sa uban pa naa sa lista  mehehe https ://t . co/hiVCx6jMPs
# tokenising: Hey Kim Fatty The third u there : D ? Fatty fatty
# tokenising: @eatyourkimchi Was there a specific reason you guys stopped doing Kpop Music Monday ?  Feel out of touch with KPOP since you stopped . :(
# tokenising: Is the #American #CriminalJustice system broken ?  Yes !  Is #BlackLivesMatter fixing the problems ?  NOPE !  #BLM just inciting a race war .
# tokenising: Sony is not anymore first to market with things awesome , but are so good at being 2nd to market but first in value . #aqua
# tokenising: TARA NA PINOY ! Join us for the brand new series " TGIF : Thank God I ' m Filipino " which begins this Sunday #FeelGodLove http ://t . co/YgRAUx6mOu
# tokenising: Kyle Seager hits solo HR in the 6th ! M ' s take 1-0 lead over the White Sox .
# tokenising: @Docs357 My 2nd Home after New England was California--70 average temperature-- quiet & nice it is here  but 6 mos eskimo-LOL
# tokenising: I expect to see news about a 32GB iPhone when I wake up tomorrow .
# tokenising: Driving west towards Banff as the sun sets on the mountains . It ' s comforting to see those hills again . Home http ://t . co/T0z2RX1U
# tokenising: From the Mouth of God My Heart Speaks  19 July 2015 Words for Today Feelings and Watchman !!!  Thank you God for ... http ://t . co/5qScrOYQ7a
# tokenising: Snoop Dogg cancelled his performance at the fair tomorrow ... Turns out he had a prior commitment for Mitch-a-Palooza .
# tokenising: Los Angeles , Nov 2 ( IANS ) Actress Keira Knightley says although she does not like some traits of her character A ... http ://t . co/KfcjX9KW
# tokenising: TOMORROW the Lovely Ladies of the #ThetaNu Chapter of #SigmaAlphaIota will be washing cars at T-Mobile on N .... http ://t . co/MPXO7sw2ac
# tokenising: @Desdemonaous The sun does not rise in the same constellation as your zodiac anymore . There has been a shift . Astrology is a myth .
# tokenising: In an unprecedented move , Apple is supporting streaming of today ' s event on " a PC with Microsoft Edge on Windows 10 " http ://t . co/ptAKXrcYmO
# tokenising: WWE , Hulk Hogan End Tie After Racist Comment : World Wrestling Entertainment Inc ( WWE . N ) said on Friday it has ... http ://t . co/sEeJXZ8b9x
# tokenising: @reduxnil HEY DUCK WHAT ARE YOU TALKING ABOUT MADURO AND tHE BOLIVARIAN REVOLUTION AHH COCKSUCKER ?? GO TO GIVE ASS IN PARK AVENUE .. EVERYDAY
# tokenising: On 6 September 2001 , Michael Jackson made a surprise appearance at the mtv vma where she danced with * Nsync . http ://t . co/EwlitvXQML
# ...
# tokenising: @CBCPolitics Harper the CPC are going to become a 3rd place party because of your reckless leadership #stopharper #cdnpoli #elxn42
# tokenising: Just watched a Teens React video on Youtube where a guy named Shant said he liked ' old music ' like Nirvana . Happy Monday .
# tokenising: With a gun to my head , The Stranger Song might be my favourite Leonard Cohen song ... only because it ' s emotional trajectory is so familiar
# tokenising: @EricTrump @GolfMonthly ERIC IM SURE YOUR DADS ON THIS RECOUNT SCAM RITE ? GEORGE SOROS  AND ALEX WOW !
# tokenising: Inmarsat ' s SwiftBroadband Soars to New Heights : Inmarsat ( LSE : ISAT . L ), the leading provider of global mobile sat ... http ://t . co/wYM5S74b
# tokenising: See you at Bentley ' s saloon on Thursday August 27th from 7pm to 11pm http ://t . co/gp4lXM07IH
# tokenising: Saturday is National Hot Dog Day .  Celebrate accordingly with ketchup &amp ; relish .
# tokenising: Fancy this Paul Dunne at the open at 40/1 would make it a good Monday
# tokenising: OK , going to be with @ThsKit on Saturday at SM Bacolod , to meet my CRUSH !!! BOOM ! XD !! hahahahqa
# tokenising: Can Silicon Valley Re-Charge Solar Energy ?: Silicon Valley innovators Apple and Google may be the best hope left ... http ://t . co/jkyct6R
# tokenising: This #FlickFriday prepare to be bewitched by #FantasticBeasts ... https ://t . co/Xx4ZhDASg5 https ://t . co/XTPrDk4MeL
# tokenising: I ' m tryna see the pacer play the raps tomorrow urg Paul George is my nigga
# tokenising: @parkiesc everythings good thanks mate ( arsenal aside ), jobs going really well - hope everythings well your end ? Should be at cobham on Sat !
# tokenising: @davidfrum He already has a friend , the blamee who " wrote " Melania ' s RNC speech .
# tokenising: Fittingly , it was premiership star Daniel Kerr who took centre stage as the Eagles capped their 25th birthday ... http ://fb . me/17VVSdTdg
# tokenising: the liberal left is very intolerant of Christians , the libs want to destroy our rights , like the 2nd amend , along with our religion
# tokenising: Happy 20th birthday , Microsoft Windows 95 : Twenty years before it launched Windows 10 -... http ://t . co/kPcGNO1Rhg http ://t . co/vx7N9HP39D
# tokenising: @MSNBC @HillaryClinton of course she does . She ' s running for Obama ' s 3rd term . More free stuff &amp ; abortion .
# tokenising: Check out the performance these brave youngsters did one Saturday morning at Sylvia Park . This is truly a great ... http ://t . co/keetJd9Q
# tokenising: #WEHO : @ChrisPipkinSC is leading the pack for a THE CARTERS : Lil Wayne , Beyonce , and Jay-Z ride Thursday at 5 : 30pm ! Grab a bike !
# tokenising: YES he is serious @michaeldean0116BRAlNDEAD FALSE FLAG u . s . a . #usaFRACKING FAKE FAGG0T FED #PlGS " EXPOSE THE LIE " @BizzyBlazinBudz#JESUS
# tokenising: Caitlyn Jenner May Face Manslaughter Charge in Malibu Crash I read it on @theneeds #video : http ://t . co/XTpygtyU1b
# tokenising: Superb . Brilliant . Stunning . We need say no more about @TheOpen so far and wish Paul Dunne good luck for Monday . #proud #thedream
# tokenising: @jrmahathir cakap je . Can we do it on tuesday ? Im in melaka . I really want to be in the picture ... Please . *U may copy and paste this*
# tokenising: @skysportsnews I would love the audio book ' The Art Of War ' by Sun Tzu , as read by Jim White !! #MountainsAndSea
# tokenising: Meanwhile they voted #Hezbollah into office . So WTF is the difference ?#Lebanon https ://t . co/iqqKbGoAad
# tokenising: it ' s August 5 in MetLife stadium , stay safe Harry , thinking about you the whole night #HarryBeCareful
# tokenising: It looks like the Curtis Painter era of Colts may begin tonight !
# tokenising: Starts Friday night Irving plaza NYC me and @bteband touring with Chiodos <- stoked
# tokenising: who ' s going to Kenny and Eric Church tomorrow and wants to tailgate with @dougzundelll and I ?
# tokenising: @BlackPanthaaYT oh lol . also turn of the turn off timer on the xbox so it dont turn off . that may also help
# tokenising: Wow . If the UFC follows through with Co headliners of Mcgregor vs Aldo and the next Rousey fight both on Dec 5th ... Im buying that fight !!!
# tokenising: Im sitting in my car listening to Frank Ocean , thinking about what could have been in life . How ' s your Monday ?
# tokenising: Who ' s ready for Iron Maiden day tomorrow @PlanetRockRadio . Maidens The Book of souls album is unleashed . http ://t . co/IEXJzAaIG2
# tokenising: After July 13th , really don ' t give a damn anymore about Greek politics . Don ' t care if it is Tsipras or Samaras . Greece is sold to the enemy .
# tokenising: Ooohh Yeah I just remembered ... I ' M GOING TO RAW TOMORROW !!!!!!! UNDERTAKER AND BROCK LESNAR !!!!!!!!! #RAWMinneapolis
# tokenising: @JohnLegere Our network is by far the 2nd best in the world , and as far as being second just you hide and watch . I work for T-Mobile !
# tokenising: Just saw " Soaked In Bleach ". All I can say is that it may very well be the best movie revealing many facts about Kurt Cobain ' s death ... : O
# tokenising: And in comes Sony with the letdown . Only one color . Clap it up ... low and slow https ://t . co/6jaRCgfvTP
# tokenising: @TuckerCarlson @GeraldoRivera @FoxNews @cnn Re-Castro debate . I just love that Geraldo ' s defence of Fidel was , he ' s charismatic , authoritative
# tokenising: @ctrm045 @therealcornett @grammy620 @megynkelly Hmm ... good to know .
# tokenising: Amazon is offering free two hour shipping or 7 . 99 one hour shipping . I ' m going to have to try this out tomorrow .
# tokenising: YOUNG MAN SEEKS EUTHANASIA FOR MENTAL ILLNESS PAIN . WILL CBD HELP ? November 28 , 2016 , Adam Maier-Clayton posts ... https ://t . co/YKlbM7IYvM
# tokenising: 4th week running going out tonight hahaha , gay nights are so good
# tokenising: Pope Francis USA tshirts on sale for $10 to Mr . Hylka-room 219 by Thursday 3pm . These will be worn 9/23 , the day the pope arrives in the US .
# tokenising: @Lejeffers3 @Emilyj12 @megynkelly seriously wow ! So awesome . Looks like I ' m going to have to get a copy to
# tokenising: Naijaprizes Proud of the Super Eagles - This perfect Monday the Super Eagles bowed out of the World Column .... http ://t . co/SjLW5boyqy
# tokenising: @ThaRightStuff @Pr0tocolsrReal They ' re natural conservatives goy
# tokenising: We are having a Sunday Worship event today at 11 : 00am in the Matthews Suite ! Come enjoy the Lord with us and connect with other Christians !
# tokenising: - Joseph Prince ( FB ): Don ' t worry about tomorrow ! Jesus , your divine servant , has gone ahead of you , p ... Don ' t wo ... http ://t . co/d88LhLHU
# tokenising: Pranab Mukherjee has just again rejected Yakub ' s 2nd mercy petition , hanging would be on as per schedule at 7am tomorrow #HangYakubNow .
# tokenising: Foo Fighters tonight and tomorrow . I ' m gonna have myself a foo-king great weekend ... and I hope YOU do too ! http ://t . co/EyRdkqzYmS
# tokenising: just out in Pinellas : Steve Miller Band , Metallica ( MINT 1st pressing ), Rolling Stones , T . Rex , Doors , Band , Neil Young , Iron Maiden , Hendrix
# tokenising: #itweetFEEDS If Taylor Swift likes it , you know it must be good ! On Monday , the blonde beauty ... http ://t . co/h1ZBbm6D1G #ff @itweetFEEDS
# tokenising: Live Tweeting Thursday takes you to Nirvana ' s " Incesticide " comp . album ! #Nirvana #Incesticide #LiveTweetingThursday
# tokenising: @thegabyconnors I know when I met him the 3rd time at DIGI when we stage kissed I started crying when he hugged me &amp ; he just kept saying ily
# tokenising: my friend is about to watch the 9th episode from 5a of teen wolf everyone wish her good luck
# tokenising: Stars aligning for Fiorina ?: Carly Fiorina rolled into Iowa on Thursday with a new status : surging presidential contender .  #news
# tokenising: Carly Fiorina is right and CNN and the RNC are wrong : http ://t . co/mpEE6FfmJG
# tokenising: no diff from @Microsoft with BitLocker =at some point , platforms should provide data at rest encryption built in https ://t . co/KATCGJER4W
# tokenising: I want to thank so much my best friend treating me out to Pizza Hut for dinner and see Ted 2 for my 30th birthday .
# tokenising: In Dunkin today I saw 4 elderly men trying to take a selfie and it may have been the cutest thing I ' ve witnessed in my entire life
# tokenising: I just need it to be Sept 4th go see Eric Church and then spend the rest of my weekend up my cabin with my best friend ...
# tokenising: I ' m so happy for @CassadeePope :) she is finally showing the world what she gots ! Blake , Hey Monday , and now just CASSADEE POPE ! <3
# tokenising: @ShawnMendes good night Shawn , I have to wake up early for School is tomorrow but I want to say that I love you
# tokenising: Steve Bannon is my Favorite Trump -Pick Yet , Breitbart is a threat to media🎉coming from a fellow Jew , Trump will ha… https ://t . co/Sn9ZxdH33m
# tokenising: lol rt @HollywoodLife Jul 17 How Louis &amp ; Briana met -- it ' s actually kind of embarrassing ... https ://t . co/vk9qz6SGWL https ://t . co/wQyj967JH8
# tokenising: Love this song ! One of my favorites for sure . Can ' t wait to see you tomorrow at The Roxy ! (@YouTube http ://t . co/Mf5Ws9cN )
# tokenising: So excited for recruitment to start at Auburn today ! These Gamma Omega Thetas are going to be great ! #wareagle [Christa and Katharine]
# tokenising: @nytimes @sapna Fake news like FBI director Comey put out right before the election .
# tokenising: #YakubVerdict : my 11yr old exclaimed , tomorrow will be the worst birthday for Yakub but his 1st bday was worst for the country ! Makes sense
# tokenising: Ben Shapiro on Steve Bannon , the alt-right , and how they ' re using Trump while he ' s too stupid to see it . #FuckTrump https ://t . co/A3qv1LNE56
# tokenising: I ' m just ready for this weekend . Tattoo Friday . Off Saturday . Jason Aldean Sunday . Only things to look forward to .
# tokenising: They should make february 13th Desperation Day .
# tokenising: ABC : Ricky Ponting and Luke Butterworth made Wednesday a tough day at the office for South Australia in their Sh ... http ://t . co/V4utMguI
# tokenising: Catching up on WWE for the week thanks to the Saturday night reruns . Seth Rollins is underappreciated .
# tokenising: Fucking true 🙈💕 #Larry #LouisTomlinson #HarryStyles #love #couple #Spain #fans #onedirection #Directioner… https ://t . co/s2WOinDJP5
# tokenising: One week until Panto rehearsals begin !! So excited !! 🎄👸🏻 #BeautyAndTheBeast #lowestoft @MarinaTheatre1 @PHApantos
# tokenising: Happy Monday ! Stop by Volare tonight for ROASTED DUCK !  HALF ROASTED CRISPY DUCK SERVED with BABY SPINACH and ... http ://t . co/sbOZD3mo
# tokenising: Woke up for the 2nd day in a row with Calibraska still being number 1 . Proud is an understatement
# tokenising: Check this video out -- Happy Hippo - The Lions sleeps tonight http ://t . co/7DfNTnp via @youtube
# tokenising: Messi has scored against every South American team , he is just the 4th player to achieve that . http ://t . co/c73n9C3Fhn
# tokenising: Thank you St David for $7 parking on a home game Saturday . #aff2012
# tokenising: @Hugodixon " more moderate " may be ! But plenty of uneducated demagogs , who have not done a day ' s work .... Starting  with Tsipras , himself !
# tokenising: I may be the only person I know who thoroughly enjoyed the Kanye West rant during the VMA ' s
# tokenising: Still head over heels in love with my ( 4th generation ) iPod . Curated to the hilt . #ipod #Apple #oldtech #personalmediadevices
# tokenising: Dean Ambrose on commentary is about the only thing I ' m interested in right now . They should be saving these guys for Sunday !
# tokenising: @bieberscinema @SpikeLSB Who ' s Deion ? That may be worse than the Paul McCartney thing
# tokenising: Hunter : Valentine ' s Day throwin it back &amp ; watchin a bunch of old @jeyyounit11 vids . This was the 1st one I ever seen http ://t . co/7oZvBKCtHP
# tokenising: Oh no not Zac Brown Band with my bestie @jmades30 #WeHateFun #Sunday #NeedStructure
# tokenising: @310KINGPIN @Venice311 Practicing for the great topless march on Venice Beach , taking it a bit further ?  A matter of principle , or meth ?
# tokenising: HAPPY 1st BIRTHDAY kids ... Inter Milan , Jordan , Kimkumkum , Lionel Messi and Milan . Thank you for your love kids http ://t . co/1OIsMtFOfg
# tokenising: This may be a little forward .... - secret-country : but can you imagine the sex Miranda Lambert & Blake ... http ://t . co/QHeebjN4
# tokenising: @ItsNotZ may be unpopular opinion but Ice Cube was the one with the lyrics .
# tokenising: GLEN HODDLE : Harry Kane ' s impact Friday was extraordinary . It was great to see Kane , the leading Premier League scorer , come on and score
# tokenising: Also , as a proud Hufflepuff , it makes me very happy that Newt Scamander is also one ! #FantasticBeasts
# tokenising: That guy looks life if a wax statue of Kim Jong Un got sick .
# tokenising: Uncharted in March may just be the thing to bring me back to Sony
# tokenising: Miley has no tits &amp ; ass but Kim and Nicki may have the same botox injection expert and Kim ain ' t got shit to lose . https ://t . co/EEjrWcrHzw
# tokenising: @charles_sings  Lorenzo Beasley . He was killed on July 17th of last year on the corner of 53rd and King Dr .  ~#Mile 5
# tokenising: Saturday Social at Phoenix Bar is the SPOT to hit in the EV if you want a FUN , GAY , DANCE PARTY ! Holly Dae and I ... http ://t . co/5CRDyX2p17
# tokenising: Good result tonight , though ! Part one of Rodgers ' Gamble paid off . Have to wait for Sunday for part two . If we win that , we ' re off ! #LFC
# tokenising: I can feel Louis saying a huge ' fuck you ' to the Zayn  it may be just me , but I ' m a lit student take my word for it
# tokenising: The XFactorUSA result ' s show will be aired in the Philippines Tomorrow Night ! @EmblemThree will definitely be in the top 12 ! Good night !
# tokenising: Attention Naruto fans ! Boruto : Naruto the Movie is hitting theaters in October . Click below to get more info ! https ://t . co/IlE7q1fnSS
# tokenising: Windows 10 user can stream the Apple event later Sept 9th , good
# tokenising: That ending of 2nd set TB by Federer , he really is the original son of Jor-el
# tokenising: Biggest problem with UFC is that Dana White seems to feed sheep to lions for ticket sales . It ' s not exactly fixed but it may as well be .
# tokenising: Melania Trump will be a long distance FLOTUS . Perhaps her inability to speak coherently extemporaneously is a factor .
# tokenising: Sound like Lexus  I ' ll believe it when I see it  https ://t . co/Sm1Xjrf2Pg
# tokenising: New mobile number coming Wednesday . DM me for the number or get me on Google+ at https ://t . co/SauTPGZolm
# tokenising: Shawn ' s a smart guy , he may be young but he knows what he ' s talking about .
# tokenising: To play Temple Run , To watch HIMYM Season 8 , orrrrr ... to sleep in readiness for tomorrow ' s morning interview - decisions are hard to make !:(
# tokenising: I would do anything to see taylor swift in concert on the 18th
# tokenising: Come on xbox , I just want to play Destiny ! I hope its better by tomorrow
# tokenising: Electoral College must reject Trump https ://t . co/5L8ai9piHj #rejecttrump #notmypresident #takingbackdemocracy #blacklivesmatter #nevertrump
# tokenising: @MaryyTaylorr31 tomorrow I ' m making the journey to Selma to celebrate pastor appreciation day/nanny ' s birthday . Better see you there
# tokenising: @hubecube_ @rocket5studios it ' s currently live on Xbox , it will be tomorrow  Steam and PC
# tokenising: I added a video to a @YouTube playlist http ://t . co/wocFZbQPnJ Tiger Woods trails by 3 midway through Sunday at the Wyndham
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
cross_validate(train_data, 10)  # will work and output overall performance of p, r, f-score when cv implemented
# Out:
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# {'precision': 0.838701091511299,
#  'recall': 0.8306545351638853,
#  'f1-score': 0.8343105442890726,
#  'accuracy': 0.8518183845629572}

# %% [markdown]
# # Question 4: Error Analysis (20 marks)

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np
# a function to make the confusion matrix readable and pretty
def confusion_matrix_heatmap(y_test, preds, labels):
    """Function to plot a confusion matrix"""
    # pass labels to the confusion matrix function to ensure right order
    # cm = metrics.confusion_matrix(y_test, preds, labels)
    cm = metrics.confusion_matrix(y_test, preds, labels=labels)
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="w")

    plt.xlabel('Predicted')
    plt.ylabel('True')

    # fix for mpl bug that cuts off top/bottom of seaborn viz:
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!

folds=len(train_data)//5
train1,train2=zip(*train_data[:folds])
test1,test2=zip(*train_data[folds:])
predicted=predict_labels(test1,train_classifier(list(zip(train1,train2))))
confusion_matrix_heatmap(test2, predicted, labels=list(set(test2)))

'''split_and_preprocess_data(0.8)

# Train the classifier
classifier = train_classifier(train_data)

# Predict labels on the test data
predicted_labels = predict_labels([data[0] for data in test_data], classifier)
true_labels = [data[1] for data in test_data]

# Display confusion matrix heatmap
confusion_matrix_heatmap(true_labels, predicted_labels, labels=['positive', 'negative'])'''
# Out:
# Training Classifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# "split_and_preprocess_data(0.8)\n\n# Train the classifier\nclassifier = train_classifier(train_data)\n\n# Predict labels on the test data\npredicted_labels = predict_labels([data[0] for data in test_data], classifier)\ntrue_labels = [data[1] for data in test_data]\n\n# Display confusion matrix heatmap\nconfusion_matrix_heatmap(true_labels, predicted_labels, labels=['positive', 'negative'])"

# %% [markdown]
# # Questions 5: Optimising pre-processing and feature extraction (30 marks)

# %% [markdown]
# **Note:** it is advisable to implement question 5 in a separate notebook where you further develop the pre-processing and feature extraction functions you implemented above.

# %%
# Finally, check the accuracy of your classifier by training on all the traning data
# and testing on the test set
# Will only work once all functions are complete
functions_complete = False  # set to True once you're happy with your methods for cross val
if functions_complete:
    print(test_data[0])   # have a look at the first test data instance
    classifier = train_classifier(train_data)  # train the classifier
    test_true = [t[1] for t in test_data]   # get the ground-truth labels from the data
    test_pred = predict_labels([x[0] for x in test_data], classifier)  # classify the test data to get predicted labels
    final_scores = precision_recall_fscore_support(test_true, test_pred, average='weighted') # evaluate
    print("Done training!")
    print("Precision: %f\nRecall: %f\nF Score:%f" % final_scores[:3])

# %% [markdown]
# REFER THE FILE "QUESTION_5.IPYNB" & "QUESTION_5RANDOMFOREST" FOR THE ANSWERS
